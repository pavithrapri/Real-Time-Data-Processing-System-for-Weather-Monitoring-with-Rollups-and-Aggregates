# %%
import smtplib
from email.mime.text import MIMEText

# %%
import requests
import time
import json
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import smtplib
from email.mime.text import MIMEText

# OpenWeatherMap API Configuration
API_KEY = '2bff56c00d1e2e022b04a3f354e94c26'  # Replace with your actual API key from OpenWeatherMap
BASE_URL = 'http://api.openweathermap.org/data/2.5/weather'
FORECAST_URL = 'http://api.openweathermap.org/data/2.5/forecast'  # For forecasts
CITIES = ['Delhi', 'Mumbai', 'Chennai', 'Bangalore', 'Kolkata', 'Hyderabad']

# Define units (metric = Celsius)
UNITS = 'metric'  # or 'imperial' for Fahrenheit
ALERT_THRESHOLD_TEMP = 35.0  # Alert if temp exceeds 35°C
CONSECUTIVE_ALERT_COUNT = 2  # Trigger alert after two consecutive updates breaching the threshold

# %%
# Function to get current weather data for a city
def get_weather(city):
    url = f"{BASE_URL}?q={city}&appid={API_KEY}&units={UNITS}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return {
            'city': city,
            'main': data['weather'][0]['main'],
            'temp': data['main']['temp'],
            'feels_like': data['main']['feels_like'],
            'humidity': data['main']['humidity'],  # Include additional parameter
            'wind_speed': data['wind']['speed'],   # Include additional parameter
            'dt': datetime.now()  # Use system time to capture real-time updates
        }
    else:
        print(f"Error retrieving data for {city}: {response.status_code}")
        return None

# Function to fetch weather data at a set interval (e.g., every 5 minutes)
def fetch_weather_data(interval=300):
    weather_data = []
    while True:
        for city in CITIES:
            try:
                data = get_weather(city)
                if data:
                    print(f"Weather data fetched for {city}: {data}")
                    weather_data.append(data)
            except Exception as e:
                print(f"Error fetching data for {city}: {e}")
        
        # Process data and check alerts after every interval
        if len(weather_data) > 0:
            process_weather_data(weather_data)
        
        time.sleep(interval)

# %%
# Function to calculate daily weather summary (rollups and aggregates)
def calculate_daily_summary(weather_data):
    df = pd.DataFrame(weather_data)
    df['date'] = df['dt'].dt.date  # Extract date

    # Group by city and date for daily rollup
    daily_summary = df.groupby(['city', 'date']).agg({
        'temp': ['mean', 'max', 'min'],
        'humidity': 'mean',
        'wind_speed': 'mean',
        'main': lambda x: x.mode()[0]  # Dominant weather condition (most frequent)
    }).reset_index()

    # Rename columns for clarity
    daily_summary.columns = ['city', 'date', 'avg_temp', 'max_temp', 'min_temp', 'avg_humidity', 'avg_wind_speed', 'dominant_weather']
    
    # Save the daily summary for future reference
    daily_summary.to_csv('daily_weather_summary.csv', index=False)
    
    return daily_summary

# Function to process and roll up weather data at the end of the day
def process_weather_data(weather_data):
    daily_summary = calculate_daily_summary(weather_data)
    print(daily_summary)
    weather_data.clear()  # Clear the data for the next day's collection

# %%
# Function to send email alerts when thresholds are breached
def send_alert(city, temp, threshold_temp):
    msg = MIMEText(f"Alert! {city} temperature exceeded {threshold_temp}°C. Current temperature: {temp}°C")
    msg['Subject'] = f"Weather Alert for {city}"
    msg['From'] = "your_email@example.com"
    msg['To'] = "recipient_email@example.com"

    with smtplib.SMTP('smtp.example.com', 587) as server:
        server.starttls()
        server.login("your_email@example.com", "your_password")
        server.send_message(msg)
    print(f"Email alert sent for {city}!")

# Function to check for temperature alerts
def check_alerts(weather_data, threshold_temp=ALERT_THRESHOLD_TEMP, consecutive_count=CONSECUTIVE_ALERT_COUNT):
    city_alerts = {}
    
    df = pd.DataFrame(weather_data).sort_values(by=['city', 'dt'])
    
    for city in CITIES:
        city_data = df[df['city'] == city]
        consecutive_breaches = 0
        
        for _, row in city_data.iterrows():
            if row['temp'] > threshold_temp:
                consecutive_breaches += 1
                if consecutive_breaches >= consecutive_count:
                    print(f"Alert! {city} has exceeded {threshold_temp}°C for {consecutive_count} consecutive updates.")
                    send_alert(city, row['temp'], threshold_temp)
            else:
                consecutive_breaches = 0  # Reset if threshold not breached

# %%
def plot_temperature_trends(summary_data):
    for city in CITIES:
        city_data = summary_data[summary_data['city'] == city]
        plt.plot(city_data['date'], city_data['avg_temp'], label=f'{city} Avg Temp')
        plt.fill_between(city_data['date'], city_data['min_temp'], city_data['max_temp'], alpha=0.2)
    
    plt.xlabel('Date')
    plt.ylabel('Temperature (°C)')
    plt.title('Daily Temperature Trends')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
def plot_alerts(alert_data):
    alert_df = pd.DataFrame(alert_data)
    alert_df['time'] = alert_df['dt'].dt.time  # Extract time for alerts

    plt.scatter(alert_df['time'], alert_df['temp'], color='red', label='Temperature Alerts')
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.title('Temperature Alerts Over Time')
    plt.show()

# %%
# Function to get weather forecast data for a city
def get_forecast(city):
    url = f"{FORECAST_URL}?q={city}&appid={API_KEY}&units={UNITS}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        forecast_data = []
        for entry in data['list']:
            forecast_data.append({
                'city': city,
                'temp': entry['main']['temp'],
                'humidity': entry['main']['humidity'],
                'wind_speed': entry['wind']['speed'],
                'main': entry['weather'][0]['main'],
                'dt': datetime.fromtimestamp(entry['dt'])
            })
        return forecast_data
    else:
        print(f"Error retrieving forecast for {city}: {response.status_code}")
        return None

# Function to fetch forecasts for all cities
def fetch_forecast_data():
    forecast_data = []
    for city in CITIES:
        data = get_forecast(city)
        if data:
            forecast_data.extend(data)
    return forecast_data

# Example of fetching forecast data
forecast_data = fetch_forecast_data()
print(forecast_data)
# Out:
# [{'city': 'Delhi', 'temp': 32.25, 'humidity': 32, 'wind_speed': 2.56, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 18, 20, 30)}, {'city': 'Delhi', 'temp': 30.47, 'humidity': 35, 'wind_speed': 2.54, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 18, 23, 30)}, {'city': 'Delhi', 'temp': 27.62, 'humidity': 38, 'wind_speed': 2.03, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 2, 30)}, {'city': 'Delhi', 'temp': 26.16, 'humidity': 42, 'wind_speed': 2.55, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 5, 30)}, {'city': 'Delhi', 'temp': 27.53, 'humidity': 40, 'wind_speed': 2.81, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 8, 30)}, {'city': 'Delhi', 'temp': 32.81, 'humidity': 26, 'wind_speed': 1.58, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 11, 30)}, {'city': 'Delhi', 'temp': 35.7, 'humidity': 19, 'wind_speed': 0.63, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 14, 30)}, {'city': 'Delhi', 'temp': 33.68, 'humidity': 24, 'wind_speed': 2.96, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 17, 30)}, {'city': 'Delhi', 'temp': 30.39, 'humidity': 36, 'wind_speed': 3.44, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 20, 30)}, {'city': 'Delhi', 'temp': 28.64, 'humidity': 43, 'wind_speed': 2.92, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 19, 23, 30)}, {'city': 'Delhi', 'temp': 27.2, 'humidity': 47, 'wind_speed': 2.4, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 2, 30)}, {'city': 'Delhi', 'temp': 26.06, 'humidity': 51, 'wind_speed': 2.91, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 5, 30)}, {'city': 'Delhi', 'temp': 27.25, 'humidity': 48, 'wind_speed': 3.65, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 8, 30)}, {'city': 'Delhi', 'temp': 31.97, 'humidity': 34, 'wind_speed': 3.14, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 11, 30)}, {'city': 'Delhi', 'temp': 35.13, 'humidity': 22, 'wind_speed': 1.86, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 14, 30)}, {'city': 'Delhi', 'temp': 33.04, 'humidity': 28, 'wind_speed': 3.72, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 17, 30)}, {'city': 'Delhi', 'temp': 29.54, 'humidity': 42, 'wind_speed': 3.83, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 20, 30)}, {'city': 'Delhi', 'temp': 28.31, 'humidity': 48, 'wind_speed': 3, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 20, 23, 30)}, {'city': 'Delhi', 'temp': 27.02, 'humidity': 52, 'wind_speed': 2.58, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 2, 30)}, {'city': 'Delhi', 'temp': 26, 'humidity': 55, 'wind_speed': 1.93, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 5, 30)}, {'city': 'Delhi', 'temp': 27.21, 'humidity': 51, 'wind_speed': 2.88, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 8, 30)}, {'city': 'Delhi', 'temp': 31.9, 'humidity': 34, 'wind_speed': 2.48, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 11, 30)}, {'city': 'Delhi', 'temp': 34.94, 'humidity': 24, 'wind_speed': 1.22, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 14, 30)}, {'city': 'Delhi', 'temp': 32.75, 'humidity': 29, 'wind_speed': 4.03, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 17, 30)}, {'city': 'Delhi', 'temp': 30.08, 'humidity': 39, 'wind_speed': 3.51, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 20, 30)}, {'city': 'Delhi', 'temp': 28.76, 'humidity': 44, 'wind_speed': 2.48, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 21, 23, 30)}, {'city': 'Delhi', 'temp': 27.62, 'humidity': 47, 'wind_speed': 1.82, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 22, 2, 30)}, {'city': 'Delhi', 'temp': 26.79, 'humidity': 49, 'wind_speed': 2.07, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 22, 5, 30)}, {'city': 'Delhi', 'temp': 27.73, 'humidity': 47, 'wind_speed': 2.78, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 22, 8, 30)}, {'city': 'Delhi', 'temp': 32.2, 'humidity': 32, 'wind_speed': 2.32, 'main': 'Clear', 'dt': datetime.datetime(2024, 10, 22, 11, 30)}, {' ...

# %%
# Start real-time data monitoring
fetch_weather_data(interval=300)  # Fetch data every 5 minutes
# Out:
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 33.05, 'feels_like': 32.53, 'humidity': 33, 'wind_speed': 2.57, 'dt': datetime.datetime(2024, 10, 18, 18, 19, 45, 315899)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 5.66, 'dt': datetime.datetime(2024, 10, 18, 18, 19, 45, 444232)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Mist', 'temp': 28.8, 'feels_like': 35.69, 'humidity': 87, 'wind_speed': 1.03, 'dt': datetime.datetime(2024, 10, 18, 18, 19, 45, 549975)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.02, 'feels_like': 26.02, 'humidity': 74, 'wind_speed': 1.33, 'dt': datetime.datetime(2024, 10, 18, 18, 19, 45, 640697)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 5.14, 'dt': datetime.datetime(2024, 10, 18, 18, 19, 45, 740891)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 27.73, 'feels_like': 31.16, 'humidity': 78, 'wind_speed': 4.63, 'dt': datetime.datetime(2024, 10, 18, 18, 19, 45, 832018)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.02     26.02     26.02          74.0
# 1    Chennai  2024-10-18     28.80     28.80     28.80          87.0
# 2      Delhi  2024-10-18     33.05     33.05     33.05          33.0
# 3  Hyderabad  2024-10-18     27.73     27.73     27.73          78.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.33           Clouds
# 1            1.03             Mist
# 2            2.57             Haze
# 3            4.63           Clouds
# 4            5.14             Haze
# 5            5.66             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 32.05, 'feels_like': 31.53, 'humidity': 35, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 24, 45, 977527)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 24, 46, 88010)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Mist', 'temp': 28.8, 'feels_like': 35.69, 'humidity': 87, 'wind_speed': 1.03, 'dt': datetime.datetime(2024, 10, 18, 18, 24, 46, 193336)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.28, 'feels_like': 26.28, 'humidity': 74, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 24, 46, 293602)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 5.14, 'dt': datetime.datetime(2024, 10, 18, 18, 24, 46, 397538)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 24, 46, 503998)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.28     26.28     26.28          74.0
# 1    Chennai  2024-10-18     28.80     28.80     28.80          87.0
# 2      Delhi  2024-10-18     32.05     32.05     32.05          35.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            1.03             Mist
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            5.14             Haze
# 5            3.60             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 32.05, 'feels_like': 31.53, 'humidity': 35, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 29, 46, 770590)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 29, 47, 17233)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.55, 'feels_like': 35.11, 'humidity': 88, 'wind_speed': 0.89, 'dt': datetime.datetime(2024, 10, 18, 18, 29, 47, 226797)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.28, 'feels_like': 26.28, 'humidity': 74, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 29, 47, 535193)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 5.14, 'dt': datetime.datetime(2024, 10, 18, 18, 29, 47, 734883)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 29, 47, 940187)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.28     26.28     26.28          74.0
# 1    Chennai  2024-10-18     28.55     28.55     28.55          88.0
# 2      Delhi  2024-10-18     32.05     32.05     32.05          35.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            0.89           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            5.14             Haze
# 5            3.60             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 32.05, 'feels_like': 31.53, 'humidity': 35, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 34, 48, 184491)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 34, 48, 380706)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.55, 'feels_like': 35.11, 'humidity': 88, 'wind_speed': 0.45, 'dt': datetime.datetime(2024, 10, 18, 18, 34, 48, 586102)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.28, 'feels_like': 26.28, 'humidity': 74, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 34, 48, 785434)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 5.14, 'dt': datetime.datetime(2024, 10, 18, 18, 34, 48, 985978)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 34, 49, 209138)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.28     26.28     26.28          74.0
# 1    Chennai  2024-10-18     28.55     28.55     28.55          88.0
# 2      Delhi  2024-10-18     32.05     32.05     32.05          35.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            0.45           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            5.14             Haze
# 5            3.60             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 32.05, 'feels_like': 31.53, 'humidity': 35, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 39, 49, 428677)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 39, 49, 644224)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.55, 'feels_like': 35.11, 'humidity': 88, 'wind_speed': 1.34, 'dt': datetime.datetime(2024, 10, 18, 18, 39, 49, 844488)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.28, 'feels_like': 26.28, 'humidity': 74, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 39, 50, 160068)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 5.14, 'dt': datetime.datetime(2024, 10, 18, 18, 39, 50, 361161)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 39, 50, 677691)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.28     26.28     26.28          74.0
# 1    Chennai  2024-10-18     28.55     28.55     28.55          88.0
# 2      Delhi  2024-10-18     32.05     32.05     32.05          35.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            1.34           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            5.14             Haze
# 5            3.60             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 32.05, 'feels_like': 31.53, 'humidity': 35, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 44, 51, 115979)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 44, 51, 314369)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.55, 'feels_like': 35.11, 'humidity': 88, 'wind_speed': 1.34, 'dt': datetime.datetime(2024, 10, 18, 18, 44, 51, 524695)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.28, 'feels_like': 26.28, 'humidity': 74, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 44, 51, 726460)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 5.14, 'dt': datetime.datetime(2024, 10, 18, 18, 44, 51, 940051)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 44, 52, 148890)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.28     26.28     26.28          74.0
# 1    Chennai  2024-10-18     28.55     28.55     28.55          88.0
# 2      Delhi  2024-10-18     32.05     32.05     32.05          35.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            1.34           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            5.14             Haze
# 5            3.60             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 32.05, 'feels_like': 31.53, 'humidity': 35, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 49, 52, 478201)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Haze', 'temp': 29.99, 'feels_like': 36.01, 'humidity': 74, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 49, 52, 691015)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.47, 'feels_like': 34.86, 'humidity': 88, 'wind_speed': 0.45, 'dt': datetime.datetime(2024, 10, 18, 18, 49, 52, 886066)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.79, 'feels_like': 28.73, 'humidity': 73, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 49, 53, 90566)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 49, 53, 288284)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 49, 53, 605950)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.79     26.79     26.79          73.0
# 1    Chennai  2024-10-18     28.47     28.47     28.47          88.0
# 2      Delhi  2024-10-18     32.05     32.05     32.05          35.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     29.99     29.99     29.99          74.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            0.45           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            1.54             Haze
# 5            3.60             Haze
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 30.05, 'feels_like': 29.99, 'humidity': 42, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 54, 53, 951846)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Thunderstorm', 'temp': 28.99, 'feels_like': 34.5, 'humidity': 79, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 54, 54, 168628)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.47, 'feels_like': 34.86, 'humidity': 88, 'wind_speed': 0.45, 'dt': datetime.datetime(2024, 10, 18, 18, 54, 54, 348888)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.79, 'feels_like': 28.73, 'humidity': 73, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 54, 54, 557043)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 54, 54, 765974)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 54, 55, 132362)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.79     26.79     26.79          73.0
# 1    Chennai  2024-10-18     28.47     28.47     28.47          88.0
# 2      Delhi  2024-10-18     30.05     30.05     30.05          42.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     28.99     28.99     28.99          79.0
#
#    avg_wind_speed dominant_weather
# 0            1.54           Clouds
# 1            0.45           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            1.54             Haze
# 5            3.60     Thunderstorm
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 30.05, 'feels_like': 29.99, 'humidity': 42, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 59, 55, 282679)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Thunderstorm', 'temp': 28.99, 'feels_like': 34.5, 'humidity': 79, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 18, 59, 55, 374355)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.35, 'feels_like': 34.48, 'humidity': 88, 'wind_speed': 1.34, 'dt': datetime.datetime(2024, 10, 18, 18, 59, 55, 458809)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.59, 'feels_like': 26.59, 'humidity': 74, 'wind_speed': 2.06, 'dt': datetime.datetime(2024, 10, 18, 18, 59, 55, 543153)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 18, 59, 55, 640121)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 18, 59, 55, 730146)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.59     26.59     26.59          74.0
# 1    Chennai  2024-10-18     28.35     28.35     28.35          88.0
# 2      Delhi  2024-10-18     30.05     30.05     30.05          42.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     28.99     28.99     28.99          79.0
#
#    avg_wind_speed dominant_weather
# 0            2.06           Clouds
# 1            1.34           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            1.54             Haze
# 5            3.60     Thunderstorm
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 30.05, 'feels_like': 29.99, 'humidity': 42, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 19, 4, 55, 884268)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Thunderstorm', 'temp': 28.99, 'feels_like': 34.5, 'humidity': 79, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 19, 4, 55, 985765)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Clouds', 'temp': 28.35, 'feels_like': 34.48, 'humidity': 88, 'wind_speed': 1.34, 'dt': datetime.datetime(2024, 10, 18, 19, 4, 56, 166359)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Clouds', 'temp': 26.59, 'feels_like': 26.59, 'humidity': 74, 'wind_speed': 2.06, 'dt': datetime.datetime(2024, 10, 18, 19, 4, 56, 364797)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 25.97, 'feels_like': 25.97, 'humidity': 94, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 19, 4, 56, 574019)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 19, 4, 56, 776409)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     26.59     26.59     26.59          74.0
# 1    Chennai  2024-10-18     28.35     28.35     28.35          88.0
# 2      Delhi  2024-10-18     30.05     30.05     30.05          42.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     25.97     25.97     25.97          94.0
# 5     Mumbai  2024-10-18     28.99     28.99     28.99          79.0
#
#    avg_wind_speed dominant_weather
# 0            2.06           Clouds
# 1            1.34           Clouds
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            1.54             Haze
# 5            3.60     Thunderstorm
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 30.05, 'feels_like': 29.99, 'humidity': 42, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 19, 9, 57, 10505)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Thunderstorm', 'temp': 28.99, 'feels_like': 34.5, 'humidity': 79, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 19, 9, 57, 211100)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Mist', 'temp': 28.39, 'feels_like': 34.61, 'humidity': 88, 'wind_speed': 2.57, 'dt': datetime.datetime(2024, 10, 18, 19, 9, 57, 427348)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Rain', 'temp': 25.36, 'feels_like': 25.96, 'humidity': 77, 'wind_speed': 2.06, 'dt': datetime.datetime(2024, 10, 18, 19, 9, 57, 630158)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 26.97, 'feels_like': 30.55, 'humidity': 89, 'wind_speed': 2.06, 'dt': datetime.datetime(2024, 10, 18, 19, 9, 57, 827856)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 19, 9, 58, 28657)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     25.36     25.36     25.36          77.0
# 1    Chennai  2024-10-18     28.39     28.39     28.39          88.0
# 2      Delhi  2024-10-18     30.05     30.05     30.05          42.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     26.97     26.97     26.97          89.0
# 5     Mumbai  2024-10-18     28.99     28.99     28.99          79.0
#
#    avg_wind_speed dominant_weather
# 0            2.06             Rain
# 1            2.57             Mist
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            2.06             Haze
# 5            3.60     Thunderstorm
# Weather data fetched for Delhi: {'city': 'Delhi', 'main': 'Haze', 'temp': 30.05, 'feels_like': 29.99, 'humidity': 42, 'wind_speed': 1.54, 'dt': datetime.datetime(2024, 10, 18, 19, 14, 58, 242026)}
# Weather data fetched for Mumbai: {'city': 'Mumbai', 'main': 'Thunderstorm', 'temp': 28.99, 'feels_like': 34.5, 'humidity': 79, 'wind_speed': 3.6, 'dt': datetime.datetime(2024, 10, 18, 19, 14, 58, 475890)}
# Weather data fetched for Chennai: {'city': 'Chennai', 'main': 'Mist', 'temp': 28.39, 'feels_like': 34.61, 'humidity': 88, 'wind_speed': 2.57, 'dt': datetime.datetime(2024, 10, 18, 19, 14, 58, 684118)}
# Weather data fetched for Bangalore: {'city': 'Bangalore', 'main': 'Rain', 'temp': 25.36, 'feels_like': 25.96, 'humidity': 77, 'wind_speed': 2.06, 'dt': datetime.datetime(2024, 10, 18, 19, 14, 58, 887176)}
# Weather data fetched for Kolkata: {'city': 'Kolkata', 'main': 'Haze', 'temp': 26.97, 'feels_like': 30.55, 'humidity': 89, 'wind_speed': 2.06, 'dt': datetime.datetime(2024, 10, 18, 19, 14, 59, 189380)}
# Weather data fetched for Hyderabad: {'city': 'Hyderabad', 'main': 'Clouds', 'temp': 26.73, 'feels_like': 29.39, 'humidity': 83, 'wind_speed': 3.09, 'dt': datetime.datetime(2024, 10, 18, 19, 14, 59, 402647)}
#         city        date  avg_temp  max_temp  min_temp  avg_humidity  \
# 0  Bangalore  2024-10-18     25.36     25.36     25.36          77.0
# 1    Chennai  2024-10-18     28.39     28.39     28.39          88.0
# 2      Delhi  2024-10-18     30.05     30.05     30.05          42.0
# 3  Hyderabad  2024-10-18     26.73     26.73     26.73          83.0
# 4    Kolkata  2024-10-18     26.97     26.97     26.97          89.0
# 5     Mumbai  2024-10-18     28.99     28.99     28.99          79.0
#
#    avg_wind_speed dominant_weather
# 0            2.06             Rain
# 1            2.57             Mist
# 2            1.54             Haze
# 3            3.09           Clouds
# 4            2.06             Haze
# 5            3.60     Thunderstorm
